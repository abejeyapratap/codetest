# %%
import numpy as np
from Common_function import *
import matplotlib.pyplot as plt
from itertools import product
import itertools
import networkx as nx
import matplotlib.pyplot as plt
from collections import defaultdict
import math
import random

x = 3  #how are is the distance set
Total_E_UGV = 500000 # in mah
Total_E_UAV = 15000 # in mah
UAV_E_cost = 1250 # in mah/km

UGV_E_cost_with_UAV = 1000 # in mah/km
UGV_E_cost_without_UAV = 800 # in mah/km
Charging_speed = 1000 # in mah/km
speed_uav =30 # km/h
speed_ugv =10 # km/h
ten_minets = 1 #how many 10 mins it take for survay 
survey_time = ten_minets/6
UAV_E_s_cost = 2500*ten_minets # mah/km
# print(UAV_E_s_cost)
# waypoints = [(20, 10), (24, 37), (36, 43), (8, 8), (0, 50), (30, 44), (28, 4), (32, 25)]
# # waypoints = [(20,10), (10,10),(15,30)]
# plan_output = "0 -> 1 -> 2 -> 0"
# plan_output = "0 -> 3 -> 4 -> 1 -> 5 -> 2 -> 7 -> 6 -> 0"
waypoints = [(20,10), (10,10), (10,30), (20,30)]
plan_output = "0 -> 1 -> 2 -> 3 -> 0"
# waypoints = [(8, 23), (31, 50), (46, 4), (50, 39), (3, 14)]
# plan_output = " 0 -> 4 -> 2 -> 3 -> 1 -> 0"
max_radius = ((Total_E_UAV - UAV_E_s_cost) / UAV_E_cost) / 2
radii = np.linspace(max_radius, 1.0, x)
ordered_points = [waypoints[int(node)] for node in plan_output.split() if node.isdigit()]
ordered_points.append(ordered_points[0])

# %%
class Node:
    def __init__(self, id, radius=None, total_time=None, level=0,end_point=None,E_UAV = None,E_UGV = None,visit_count = 0,max_childen=0):
        self.id = id
        self.radius = radius
        self.total_time = total_time
        self.level = level
        self.children = []
        self.E_UAV = E_UAV
        self.E_UGV = E_UGV
        self.visit_count = 0
        self.end_point = end_point
        self.value = 0.0  # For MCTS
        self.parent = None  # For MCTS
        self.max_childen = max_childen 
        self.expanded_children = 0
        
    def add_child(self, node):
        """Adds a child to the current node."""
        node.level = self.level + 1
        node.parent = self  # Set parent for MCTS
        self.children.append(node)
        
    def delete_child(self, node):
        """Removes a child from the current node."""
        if node in self.children:
            self.children.remove(node)

    

    def traverse(self):
        """Traverses and displays the tree starting from the current node."""
        # print(f"Node ID: {self.id}, Visits: {self.visit_count}, Value: {self.value}")
        print(f"Node ID: {self.id}, Radius: {self.radius}, Total Time: {self.total_time}, Level: {self.level}, E_UAV: {self.E_UAV}, E_UGV: {self.E_UGV}, Visits: {self.visit_count}, Value: {self.value},max_child: {self.max_childen}")
        for child in self.children:
            child.traverse()

    def get_nodes(self):
        """Returns all nodes in the tree starting from the current node."""
        nodes = [self]
        for child in self.children:
            nodes.extend(child.get_nodes())
        return nodes

    def ucb1(self, exploration_constant=4):
        """Calculates the UCB1 value for MCTS."""

        if self.visit_count == 0:
            # self.visit_count = 0.00001
            return float('inf')
        
        # Handling the root node
        if self.parent is None or self.parent.visit_count == 0:
            return self.value

        avg_value = self.value / self.visit_count

        exploration_term = exploration_constant * math.sqrt(2 * math.log(self.parent.visit_count) / self.visit_count)
        # print(self.parent.id, , self.visit_count,exploration_term)
        ucb1_value = avg_value + exploration_term
        
        return ucb1_value


    def fully_expanded(self,waypoints):
        """Checks if the node is fully expanded."""
        return self.level == len(waypoints)   # 

    def update(self, reward):
        """Updates the node's value and visit count based on the given reward."""
        self.visit_count += 1
        self.value += reward

    def select(self, waypoints):
        """Select a node (can be current or its child) based on the UCB1 scores."""
        current_node = self
        while current_node.children and not current_node.fully_expanded(waypoints):
            best_child = current_node.best_child()
            if best_child.ucb1() > current_node.ucb1():
                current_node = best_child
            else:
                break         
        return current_node



    def best_child(self):
        """Returns the child node with the highest UCB1 score."""
        return max(self.children, key=lambda node: node.ucb1(), default=None) # Max UCB1 is the best.

# %%
math.sqrt(2 * math.log(1) / 1)
# Out:
# 0.0

# %%
pow(5.3,-1)*100
# Out:
# 18.867924528301888

# %%
def add_node_with_random_radius(parent, nodes_in_order,old_nodes_counter, r):
    # print(f"data_in nodes_in_order :{nodes_in_order}")
    waypoint_index = parent.level + 1
    
    # print(f"waypoint_index:{waypoint_index},with radius:{r}")
    if waypoint_index >= len(nodes_in_order):
        print(f"0000000 {waypoint_index} > {len(nodes_in_order)} 00000000")
        return
    if waypoint_index == 1: # starting point, no charging need to be cal for the begining path
        
        radius_set, UGV_path, UAV_path, UAV_path_segment_distance,UGV_outer_path, UGVD_inter_without_drone, UGVD_inter_with_drone, final_wait_time= compute_path_for_one_point(ordered_points, waypoint_index, r, speed_ugv, speed_uav, survey_time)
        UGV_out_distance = compute_distance(ordered_points[0], UAV_path[0][0])
        UGV_inter_distance = compute_distance(UGV_path[0],UGV_path[1])
        UGV_distance = UGV_out_distance + UGV_inter_distance
        UAV_distances =UAV_path_segment_distance
        
        UGV_Trip_Cost = UGVD_inter_without_drone[0] * UGV_E_cost_without_UAV + UGV_out_distance * UGV_E_cost_with_UAV
        UAV_Trip_Cost = UAV_distances * UAV_E_cost + UAV_E_s_cost

        charging_distance = UGVD_inter_with_drone[0]
        
        UGV_energy_remaining = Total_E_UGV - UGV_Trip_Cost
        UAV_energy_remaining = Total_E_UAV - UAV_Trip_Cost
        if UGV_energy_remaining < 0 or UAV_energy_remaining < 0:
            print("1111111 UGV_energy_remaining Or  UAV_energy_remaining < 0 11111111111")
            parent.visit_count +=1
            return  None , old_nodes_counter # Indicating mission failed for both
        
        charging_distance = UGVD_inter_with_drone[0]
        if UAV_energy_remaining < Total_E_UAV:
            charge_amount = min(Charging_speed * charging_distance , UAV_Trip_Cost, UGV_energy_remaining)
            UGV_energy_remaining -= charge_amount
            UAV_energy_remaining += charge_amount
            
        if UGV_energy_remaining < 0 or UAV_energy_remaining < 0:
            parent.visit_count +=1
            return  None , old_nodes_counter # Indicating mission failed for both
        else:
            pass_flag = 0
        total_time = parent.total_time  + final_wait_time +UGV_distance / speed_ugv

    elif waypoint_index == (len(nodes_in_order) -1): # Ending point, don't charge the drone on the wayback
        
        UAV_path = []
        final_wait_time = 0
        UGV_path = [parent.end_point,ordered_points[-1]]
        UGV_distance = compute_distance(parent.end_point,ordered_points[-1])
        total_time = parent.total_time + UGV_distance / speed_ugv 

        UGV_energy_remaining =parent.E_UGV
        UAV_energy_remaining =parent.E_UAV
        
        UGV_Trip_Cost = UGV_distance * UGV_E_cost_with_UAV
        UAV_Trip_Cost = 0
        UGV_energy_remaining -= UGV_Trip_Cost
        if UGV_energy_remaining < 0:
            parent.visit_count +=1
            return  None , old_nodes_counter # Indicating mission failed for both
        else:
            pass_flag = 2
        
    else: #Any Mid point on the way 
        
        radius_set, UGV_path, UAV_path, UAV_path_segment_distance,UGV_outer_path, UGVD_inter_without_drone, UGVD_inter_with_drone, final_wait_time= compute_path_for_one_point(ordered_points, waypoint_index, r, speed_ugv, speed_uav, survey_time)
        UGV_inter_distance = compute_distance(UGV_path[0],UGV_path[1])
        # print(f"parent.end_point:{parent.end_point}")
        UGV_out_distance = compute_distance(parent.end_point,UGV_path[0])

        UGV_distance = UGV_out_distance + UGV_inter_distance

        UAV_distances =UAV_path_segment_distance
        
        UGV_Trip_Cost = UGVD_inter_without_drone[0] * UGV_E_cost_without_UAV + UGV_out_distance * UGV_E_cost_with_UAV
        UAV_Trip_Cost = UAV_distances * UAV_E_cost + UAV_E_s_cost
        
        UAV_energy_remaining = parent.E_UAV
        UGV_energy_remaining = parent.E_UGV
        
        charging_distance = UGV_out_distance
        if UAV_energy_remaining < Total_E_UAV:
            charge_amount = min(Charging_speed * charging_distance , (Total_E_UAV - UAV_energy_remaining), UGV_energy_remaining)
            UGV_energy_remaining -= charge_amount
            UAV_energy_remaining += charge_amount
            
        
        UGV_energy_remaining = UGV_energy_remaining - UGV_Trip_Cost
        UAV_energy_remaining = UAV_energy_remaining - UAV_Trip_Cost
        
        charging_distance = UGVD_inter_with_drone[0]
        if UAV_energy_remaining < Total_E_UAV:
            charge_amount = min(Charging_speed * charging_distance , (Total_E_UAV - UAV_energy_remaining), UGV_energy_remaining)
            UGV_energy_remaining -= charge_amount
            UAV_energy_remaining += charge_amount
            
        
        if UGV_energy_remaining < 0 or UAV_energy_remaining < 0:
            parent.visit_count +=1
            return  None , old_nodes_counter # Indicating mission failed for both
        else: 
            pass_flag = 0   
            total_time = parent.total_time  + UGV_distance / speed_ugv + final_wait_time

        
        
    if pass_flag == 1:
        # print("2222222222222222")
        parent.visit_count +=1
        # parent.reward = 0 
        # print(f"No plan find, return None, {old_nodes_counter}")
        return None , old_nodes_counter
        
       
        
        
    if pass_flag == 2:
        node_counter = old_nodes_counter+1 
        child = Node(id=node_counter, radius=None, total_time=total_time)
        parent.add_child(child)
        child.E_UGV = UGV_energy_remaining
        child.E_UAV = UAV_energy_remaining
        child.visit_count +=1
        child.end_point = UGV_path[-1]  # Placeholder; replace with appropriate logic
        # reward = simulate(child, waypoints)
        # backpropagate(child, reward)
        # child.traverse()
        # print("33333333333333333333")
        return  child , node_counter
    else:
        node_counter = old_nodes_counter+1  # Increment global node ID counter
        child = Node(id=node_counter, radius=r, total_time=total_time)
        parent.add_child(child)
        child.E_UGV = UGV_energy_remaining
        child.E_UAV = UAV_energy_remaining
        # child.visit_count +=1
        child.end_point = UGV_path[-1]  # Placeholder; replace with appropriate logic
        
        # print("444444444444444444444")
        # print(f" child id :{child.id},child level :{child.level}")
        return  child , node_counter

# %%
def simulate(node, waypoints):
    # If the node is at the fully expanded depth
    if node.fully_expanded(waypoints):
        # Return the negative value of total_time as the reward
        print(f"Fully expaned,as we min the total_time, so we make the reward inv of total time * 100{pow(node.total_time,-1)*100}")
        return pow(node.total_time,-1)*100
    else:
        # For non-fully expanded nodes, return a default value or continue with a simplified simulation
        print("not fully expaned, so reward = 0 ")
        return 0

# Adjusting the expand_mcts function to introduce randomness
def backpropagate(node, reward):
    while node:
        node.update(reward*node.level)
        # print(f"backpropagate reward :{reward},to node :{node.id}")
        node = node.parent

# %%
random.choice(radii)
# Out:
# 1.0

# %%
def attempt_expansion_for_node(node, n, shuffled_radii, waypoints, nodes_in_order):
    # Extract the radii that have already been used for the children of this node
    used_radii = [child.radius for child in node.children]

    while not node.fully_expanded(waypoints):
        used_radii = [child.radius for child in node.children]
        used_radii_set = set(used_radii)
        available_radii = [r for r in shuffled_radii if r not in used_radii_set]
        print(f"picked node {node.id} to play out,it has {available_radii} available_radii")
        if node.level == len(waypoints) -1 and node.children:
            node.visit_count +=1
            print("!!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!")
            break
        if node.fully_expanded(waypoints):
            available_radii = []
            print("Is fully exapned ")
            break
        if available_radii:
            r = random.choice(available_radii)
        else:
            break
        # Skip this radius if it's already been used for a child of this node
        if r in used_radii:
            print(f"Node {node.id} has no more expansion with all of those radius used {used_radii}")
            continue
        
        # Try to expand the current node with the current radius
        print(f"during the playout, choose random r: {r} ")
        child, new_n = add_node_with_random_radius(node, nodes_in_order, n, r)
        # new_n +=1
        used_radii.append(r)
        
        # If expansion was successful, move to the child node and update n
        if child is not None:
            
            print(f"Which added a new nodes {child.id}")
            node.expanded_children +=1
            node = child
            n = new_n
            used_radii = []
            # Add this radius to the used_radii listif :
          
            if node.fully_expanded(waypoints) :
                # available_radii = None
                print("Is fully exapned ")
                break
            # print(used_radii)
        else:
            print(f"unable to expland as the return is None")
            break
    return n, node

# %%
def MCTS_v2(root, n,nodes_in_order, waypoints, iterations=15):
    # shuffled_radii = random.sample(sorted(radii), len(radii))
    picked_node_ids =[]
    for _ in range(iterations):
        # print("leaf_node")
        # root.traverse()
        # print("root")
        # Selection !!!! 
        shuffled_radii = random.sample(sorted(radii), len(radii))
        leaf_node = root.select(waypoints)
        print(f"the ucb1 chose the {leaf_node.id} ")
      
        leaf_node.visit_count +=1
        if leaf_node.fully_expanded(waypoints):
            print("at the end no more to expand")
            leaf_node.parent.max_childen = 1
            continue
        # leaf_node.traverse()
        # print(f"I chose a node {leaf_node.id} that have {len(leaf_node.children)} children, and the node should have :{leaf_node.max_childen} ")
        # If the selected node is None, continue to the next iteration
        if leaf_node is None:
            print("passed")
            continue
        if leaf_node.level == len(waypoints) -1:
            
            print("!!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
            continue
        # 2. Expansion
        if len(leaf_node.children) < leaf_node.max_childen:
            print("expanding to the max_childen")

            # nodes_to_explore = [leaf_node]  # Start exploring from the selected leaf node
            
            # while nodes_to_explore:
            current_node = leaf_node  # Get the first node from the list
            
            shuffled_radii = [r for r in shuffled_radii if r not in [child.radius for child in current_node.children]] # selest form shuffled_radii if not in current_node.child 
            print(f"!!!!!!!shuffled_radii:{shuffled_radii}!!!!!!!!!!!!!!")
            for r in shuffled_radii:
                child, new_n = add_node_with_random_radius(current_node, nodes_in_order, n, r)
                if child == None:
                    current_node.max_childen -=1
                    print(f"can't expanded with radius {r}, so decress the max children flag to {current_node.max_childen} ")
                else:
                    child.max_childen = current_node.max_childen
                current_node.expanded_children +=1
                
                # print(f"N = {n}")
                n = new_n
    
        if not leaf_node.children or leaf_node is None:
            continue
    
           
        
        available_children = [child for child in leaf_node.children if child.id not in picked_node_ids]
        if not available_children:  # If no more children are left
            # Reset picked_node_ids or handle this scenario differently
            picked_node_ids = []
            available_children = leaf_node.children  # Reset available children
        node = random.choice(available_children)
        picked_node_ids.append(node.id)
        
        print(f"picked node {node.id} to play out,it has {len(available_children)} available_children")
        print(f"reward = :{simulate(node, waypoints)}")
        n,node = attempt_expansion_for_node(node, n, shuffled_radii, waypoints, nodes_in_order)


        # Backpropagate 
        if node.fully_expanded(waypoints):

            print("backpropagate")
            reward = simulate(node, waypoints)
            backpropagate(node, reward)
    

        print("-----------end ---------\n")
    print(f"picked_node_ids:{picked_node_ids}")
    
    return root.best_child()  # Return the best child of the root based on UCB1

# %%
nodes_in_order = plan_output.split()
nodes_in_order = [int(node) for node in nodes_in_order if node.isdigit()]
root = Node(id=0, radius=None, total_time=0, visit_count=0, max_childen = len(radii),level = 0)
# print(f"nodes_in_order :{nodes_in_order},waypoints:{waypoints}")
n = 0

node = root
best_node = MCTS_v2(root, n,nodes_in_order,waypoints,5000)
# print(best_node.id,best_node.best_child,)
# Out:
# the ucb1 chose the 0
# expanding to the max_childen
# !!!!!!!shuffled_radii:[5.0, 3.0, 1.0]!!!!!!!!!!!!!!
# 10.0 - 15.0
# 10.0 - 13.0
# 10.0 - 11.0
# picked node 2 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 2 to play out,it has [5.0, 3.0, 1.0] available_radii
# during the playout, choose random r: 3.0
# 13.0 - 10.0
# Which added a new nodes 4
# picked node 4 to play out,it has [5.0, 3.0, 1.0] available_radii
# during the playout, choose random r: 1.0
# 20.0 - 19.0
# Which added a new nodes 5
# picked node 5 to play out,it has [5.0, 3.0, 1.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 6
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.599865909204144
# -----------end ---------
#
# the ucb1 chose the 1
# expanding to the max_childen
# !!!!!!!shuffled_radii:[3.0, 5.0, 1.0]!!!!!!!!!!!!!!
# 13.0 - 10.0
# 15.0 - 10.0
# 11.0 - 10.0
# picked node 7 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 7 to play out,it has [3.0, 5.0, 1.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# Which added a new nodes 10
# picked node 10 to play out,it has [3.0, 5.0, 1.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 11
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10018.671922474123093
# -----------end ---------
#
# the ucb1 chose the 3
# expanding to the max_childen
# !!!!!!!shuffled_radii:[5.0, 3.0, 1.0]!!!!!!!!!!!!!!
# 15.0 - 10.0
# 13.0 - 10.0
# 11.0 - 10.0
# picked node 13 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 13 to play out,it has [5.0, 3.0, 1.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 4
# picked node 5 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 5 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# expanding to the max_childen
# !!!!!!!shuffled_radii:[5.0, 1.0]!!!!!!!!!!!!!!
# 15.0 - 10.0
# 11.0 - 10.0
# picked node 16 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 16 to play out,it has [5.0, 1.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# Which added a new nodes 17
# picked node 17 to play out,it has [5.0, 1.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 18
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.97040717839615
# -----------end ---------
#
# the ucb1 chose the 15
# expanding to the max_childen
# !!!!!!!shuffled_radii:[3.0, 5.0, 1.0]!!!!!!!!!!!!!!
# 20.0 - 17.0
# can't expanded with radius 3.0, so decress the max children flag to 2
# 20.0 - 15.0
# can't expanded with radius 5.0, so decress the max children flag to 1
# 20.0 - 19.0
# picked node 19 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 19 to play out,it has [3.0, 5.0, 1.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 20
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.97040717839615
# -----------end ---------
#
# the ucb1 chose the 17
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# expanding to the max_childen
# !!!!!!!shuffled_radii:[1.0, 3.0]!!!!!!!!!!!!!!
# 20.0 - 19.0
# 20.0 - 17.0
# picked node 22 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 22 to play out,it has [1.0, 3.0] available_radii
# during the playout, choose random r: 3.0
# Which added a new nodes 23
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.599865909204144
# -----------end ---------
#
# the ucb1 chose the 21
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 17
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 21 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [1.0, 3.0, 5.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 24
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10016.975246271262307
# -----------end ---------
#
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 21
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 17 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 17 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 4
# picked node 5 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 5 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 21
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 22 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 22 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 16 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 16 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 16
# picked node 21 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 4
# picked node 5 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 5 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 17
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 17 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 17 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 16 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 16 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 8
# expanding to the max_childen
# !!!!!!!shuffled_radii:[5.0, 3.0, 1.0]!!!!!!!!!!!!!!
# 20.0 - 15.0
# can't expanded with radius 5.0, so decress the max children flag to 2
# 20.0 - 17.0
# can't expanded with radius 3.0, so decress the max children flag to 1
# 20.0 - 19.0
# picked node 25 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 25 to play out,it has [5.0, 3.0, 1.0] available_radii
# during the playout, choose random r: 3.0
# Which added a new nodes 26
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10018.356886487533792
# -----------end ---------
#
# the ucb1 chose the 9
# expanding to the max_childen
# !!!!!!!shuffled_radii:[5.0, 1.0, 3.0]!!!!!!!!!!!!!!
# 20.0 - 15.0
# 20.0 - 19.0
# 20.0 - 17.0
# picked node 28 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 28 to play out,it has [5.0, 1.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 30
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.31969584590848
# -----------end ---------
#
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# expanding to the max_childen
# !!!!!!!shuffled_radii:[1.0, 5.0]!!!!!!!!!!!!!!
# 20.0 - 19.0
# 20.0 - 15.0
# can't expanded with radius 5.0, so decress the max children flag to 2
# picked node 10 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 10 to play out,it has [1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 29
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 28
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 28
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 27 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 27 to play out,it has [5.0, 1.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 32
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10018.356886487533792
# -----------end ---------
#
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 29 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 29 to play out,it has [5.0, 1.0, 3.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 33
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.97040717839615
# -----------end ---------
#
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 29
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 29
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 28
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 29 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 29 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 8 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 8 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 9
# picked node 27 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 27 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 31 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 31 to play out,it has [5.0, 3.0, 1.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 34
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.97040717839615
# -----------end ---------
#
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 10 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 10 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 7 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 7 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 28
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 28 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 28 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 9 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 9 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 16
# picked node 21 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 4 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 4 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 9
# picked node 29 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 29 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 31 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 31 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 8 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 8 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 19
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 20
# at the end no more to expand
# the ucb1 chose the 19
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 20
# at the end no more to expand
# the ucb1 chose the 19
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 20
# at the end no more to expand
# the ucb1 chose the 20
# at the end no more to expand
# the ucb1 chose the 19
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 20
# at the end no more to expand
# the ucb1 chose the 19
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 15
# picked node 19 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 19 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 21 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 15 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 15 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 28 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 28 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 7 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 7 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 17
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 17 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 17 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 4 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 4 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 29
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 27 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 27 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 9 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 9 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 9
# picked node 27 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 27 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 31 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 31 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 7 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 7 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 16
# picked node 22 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 22 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 15 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 15 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 29
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 28
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 28 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 28 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 9 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 9 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 21
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 21 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 16 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 16 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 9
# picked node 29 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 29 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 8
# picked node 25 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 25 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 9
# picked node 27 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 27 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 8 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 8 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 17
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 21 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 4
# picked node 5 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 5 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 17 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 17 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 4 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 4 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# Which added a new nodes 35
# picked node 35 to play out,it has [3.0, 5.0, 1.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 36
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10018.272208451087483
# -----------end ---------
#
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 4
# picked node 35 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 35 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 4
# picked node 35 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 35 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 4
# picked node 5 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 5 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 15 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 15 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 12
# expanding to the max_childen
# !!!!!!!shuffled_radii:[5.0, 1.0, 3.0]!!!!!!!!!!!!!!
# 20.0 - 15.0
# can't expanded with radius 5.0, so decress the max children flag to 2
# 20.0 - 19.0
# 20.0 - 17.0
# can't expanded with radius 3.0, so decress the max children flag to 1
# picked node 37 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 37 to play out,it has [5.0, 1.0, 3.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 38
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.31969584590848
# -----------end ---------
#
# the ucb1 chose the 14
# expanding to the max_childen
# !!!!!!!shuffled_radii:[1.0, 5.0, 3.0]!!!!!!!!!!!!!!
# 20.0 - 19.0
# 20.0 - 15.0
# 20.0 - 17.0
# picked node 40 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [1.0, 5.0, 3.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 42
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.31969584590848
# -----------end ---------
#
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 41
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 41 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 41 to play out,it has [5.0, 1.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 43
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10016.975246271262304
# -----------end ---------
#
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 41
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 41
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 39 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 39 to play out,it has [1.0, 5.0, 3.0] available_radii
# during the playout, choose random r: 1.0
# Which added a new nodes 44
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10016.393442622950822
# -----------end ---------
#
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 40 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 13 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 13 to play out,it has [1.0, 3.0, 5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 14
# picked node 39 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 39 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 41
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 41 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 41 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 12 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 12 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 39 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 39 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 14 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 14 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 14
# picked node 41 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 41 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 12 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 12 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 40 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 14
# picked node 40 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 14 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 14 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 41
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 41 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 41 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 13 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 13 to play out,it has [3.0, 1.0, 5.0] available_radii
# during the playout, choose random r: 1.0
# 20.0 - 19.0
# Which added a new nodes 45
# picked node 45 to play out,it has [3.0, 1.0, 5.0] available_radii
# during the playout, choose random r: 5.0
# Which added a new nodes 46
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10016.975246271262307
# -----------end ---------
#
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# expanding to the max_childen
# !!!!!!!shuffled_radii:[3.0, 5.0]!!!!!!!!!!!!!!
# 20.0 - 17.0
# 20.0 - 15.0
# can't expanded with radius 5.0, so decress the max children flag to 2
# picked node 45 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 45 to play out,it has [3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# picked node 47 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 47 to play out,it has [3.0, 5.0, 1.0] available_radii
# during the playout, choose random r: 3.0
# Which added a new nodes 48
# Is fully exapned
# backpropagate
# Fully expaned,as we min the total_time, so we make the reward inv of total time * 10017.599865909204144
# -----------end ---------
#
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# picked node 47 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 47 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 13
# picked node 45 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 45 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# picked node 47 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 47 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 12 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 12 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 13 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 13 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 14
# picked node 41 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 41 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 14 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 14 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 31 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 31 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 9 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 9 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 4
# picked node 35 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 35 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 15 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 15 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 40 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# picked node 45 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# ...
# reward = :0
# picked node 29 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 31 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 31 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 7 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 7 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 40 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 37
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 37
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 37
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 12
# picked node 37 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 37 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 46
# at the end no more to expand
# the ucb1 chose the 45
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# picked node 45 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 45 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 43
# at the end no more to expand
# the ucb1 chose the 41
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 41 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 41 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 12 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 12 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 3.0
# 20.0 - 17.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 15
# picked node 19 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 19 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 16
# picked node 17 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 17 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 4
# picked node 5 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 5 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 4 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 4 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 26
# at the end no more to expand
# the ucb1 chose the 25
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 8
# picked node 25 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 25 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 9
# picked node 29 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 29 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 30
# at the end no more to expand
# the ucb1 chose the 28
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 28 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 28 to play out,it has [5.0, 1.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 8 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 8 to play out,it has [3.0, 5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 48
# at the end no more to expand
# the ucb1 chose the 47
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 13
# picked node 45 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 45 to play out,it has [3.0, 1.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 44
# at the end no more to expand
# the ucb1 chose the 39
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 42
# at the end no more to expand
# the ucb1 chose the 40
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 14
# picked node 39 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 39 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 13 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 13 to play out,it has [5.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 21
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 21 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 21 to play out,it has [1.0, 3.0, 5.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 15
# picked node 19 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 19 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 18
# at the end no more to expand
# the ucb1 chose the 17
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 17 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 17 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 2
# picked node 15 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 15 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 34
# at the end no more to expand
# the ucb1 chose the 31
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 31 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 31 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 32
# at the end no more to expand
# the ucb1 chose the 27
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 33
# at the end no more to expand
# the ucb1 chose the 29
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 9
# picked node 27 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 27 to play out,it has [1.0, 5.0, 3.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 11
# at the end no more to expand
# the ucb1 chose the 10
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 7
# picked node 10 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 10 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 1
# picked node 9 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 9 to play out,it has [] available_radii
# -----------end ---------
#
# the ucb1 chose the 14
# picked node 40 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 40 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 38
# at the end no more to expand
# the ucb1 chose the 37
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 12
# picked node 37 to play out,it has 1 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 37 to play out,it has [5.0, 3.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 3
# picked node 12 to play out,it has 3 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 12 to play out,it has [5.0, 3.0] available_radii
# during the playout, choose random r: 5.0
# 20.0 - 15.0
# unable to expland as the return is None
# -----------end ---------
#
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 24
# at the end no more to expand
# the ucb1 chose the 21
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 23
# at the end no more to expand
# the ucb1 chose the 22
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 16
# picked node 22 to play out,it has 2 available_children
# not fully expaned, so reward = 0
# reward = :0
# picked node 22 to play out,it has [3.0, 5.0, 1.0] available_radii
# !!!!!!!!!!!!!!!!!!!!! second to last and has child already !!!!!!!!!!!!!!!!!!!!!
# -----------end ---------
#
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 6
# at the end no more to expand
# the ucb1 chose the 5
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# the ucb1 chose the 36
# at the end no more to expand
# the ucb1 chose the 35
# !!!!!!!!!!!!!!!!!!!!! second to last passed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# picked_node_ids:[19, 17, 15, 31, 27, 10, 9, 40, 37, 12, 22]

# %%
def print_best_child_ids(node):
    
    # Base case: if the node has no children, return
    if not node.children:
        return
    
    best_child_node = node.best_child()
    if best_child_node:  # It's possible best_child() returns None
        print(best_child_node.id)
        print_best_child_ids(best_child_node)

# Call the function starting from the root node
print_best_child_ids(root)
# Out:
# 2
# 4
# 35
# 36

# %%
root.traverse()
draw_tree(root)
result = find_min_total_time_node_at_level(root,4)
print(f"--------------------------Best Result: {result}-------------------------------------")
# Out:
# Node ID: 0, Radius: None, Total Time: 0, Level: 0, E_UAV: None, E_UGV: None, Visits: 19, Value: 0.0,max_child: 3
# Node ID: 1, Radius: 5.0, Total Time: 1.2071067811865475, Level: 1, E_UAV: 4540.097098824646, E_UGV: 488782.48557872785, Visits: 143, Value: 108.64620565189148,max_child: 3
# Node ID: 7, Radius: 3.0, Total Time: 2.8313708498984758, Level: 2, E_UAV: 7031.991476329811, E_UGV: 462692.07402478915, Visits: 142, Value: 73.28465930503849,max_child: 2
# Node ID: 10, Radius: 3.0, Total Time: 3.6556349186104042, Level: 3, E_UAV: 3063.9829526596222, E_UGV: 451061.5653720258, Visits: 126, Value: 56.01576742236928,max_child: 1
# Node ID: 11, Radius: None, Total Time: 5.355634918610404, Level: 4, E_UAV: 3063.9829526596222, E_UGV: 434061.5653720258, Visits: 141, Value: 74.68768989649237,max_child: 0
# Node ID: 31, Radius: 1.0, Total Time: 3.6647041832318092, Level: 3, E_UAV: 8031.991476329811, E_UGV: 449560.70317489066, Visits: 123, Value: 53.91122153518845,max_child: 1
# Node ID: 34, Radius: None, Total Time: 5.564704183231809, Level: 4, E_UAV: 8031.991476329811, E_UGV: 430560.70317489066, Visits: 137, Value: 71.8816287135846,max_child: 0
# Node ID: 8, Radius: 5.0, Total Time: 2.914213562373095, Level: 2, E_UAV: 4080.194197649292, E_UGV: 462564.9711574557, Visits: 105, Value: 36.713772975067585,max_child: 1
# Node ID: 25, Radius: 1.0, Total Time: 3.5475468957064282, Level: 3, E_UAV: 3080.1941976492926, E_UGV: 453433.6003075572, Visits: 119, Value: 55.07065946260138,max_child: 1
# Node ID: 26, Radius: None, Total Time: 5.447546895706428, Level: 4, E_UAV: 3080.1941976492926, E_UGV: 434433.6003075572, Visits: 137, Value: 73.42754595013517,max_child: 0
# Node ID: 9, Radius: 1.0, Total Time: 2.8404401145198808, Level: 2, E_UAV: 10000.0, E_UGV: 463191.211827654, Visits: 173, Value: 107.29397902367684,max_child: 3
# Node ID: 27, Radius: 5.0, Total Time: 3.947546895706428, Level: 3, E_UAV: 3540.097098824646, E_UGV: 448973.69740638183, Visits: 127, Value: 55.07065946260138,max_child: 1
# Node ID: 32, Radius: None, Total Time: 5.447546895706428, Level: 4, E_UAV: 3540.097098824646, E_UGV: 433973.69740638183, Visits: 139, Value: 73.42754595013517,max_child: 0
# Node ID: 28, Radius: 1.0, Total Time: 3.873773447853214, Level: 3, E_UAV: 10000.0, E_UGV: 449059.8409777555, Visits: 123, Value: 51.95908753772544,max_child: 1
# Node ID: 30, Radius: None, Total Time: 5.773773447853214, Level: 4, E_UAV: 10000.0, E_UGV: 430059.8409777555, Visits: 133, Value: 69.27878338363392,max_child: 0
